# %%
import cv2

face_cascade_path = '../models/xml/haarcascade_frontalface_default.xml'
eye_cascade_path = '../models/xml/haarcascade_eye.xml'

face_cascade = cv2.CascadeClassifier(face_cascade_path)
eye_cascade = cv2.CascadeClassifier(eye_cascade_path)

img = cv2.imread('../data/lena.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
 
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
ratio = 0.25
#複数の顔の場合に必要
for (x,y,w,h) in faces:
    plt.imshow(img[int(y-h*ratio):int(y+h*(1+ratio)), int(x-w*ratio):int(x+w*(1+ratio)), :])

# %%
264/4
# Out:
# 66.0

# %%
faces
# Out:
# array([[252,  65, 264, 264]], dtype=int32)

# %%
img.shape
# Out:
# (615, 615, 3)

# %%
if (y-h*ratio<0) | (y+h*(1+ratio)>img.shape[0]) | (x-w*ratio<0) | (x+w*(1+ratio)>img.shape[1]):
# Out:
#   File "<ipython-input-68-03ee656246fd>", line 1
#     if y-h*ratio<0
#                   ^
# SyntaxError: invalid syntax

# %%
import os

ratio = 0.25

category_path = "../data/org"

for category in [i for i in os.listdir(category_path) if i!=".DS_Store"]:
    folder_path = category_path + "/" + category
    for folder in [i for i in os.listdir(name_path) if i!=".DS_Store"]:
        for name in [i for i in os.listdir(name_path) if i!=".DS_Store"]:
            img_path = folder_path + "/" + name
            for img_fn in [i for i in os.listdir(folder) if i!=".DS_Store"]:
                img_path = img_path + "/" + img_fn
                img = cv2.imread(img_path)
                try:
                    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                except:
                    continue
                faces = face_cascade.detectMultiScale(gray, 1.3, 5)
                for (x,y,w,h) in faces:
                    try:
                        plt.imshow(img[int(y-h*ratio):int(y+h*(1+ratio)), int(x-w*ratio):int(x+w*(1+ratio)), :])
                    except:
                        continue
                    #cv2.imwrite('data/dst/lena_opencv_red.jpg', img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-bce03ffb69d8> in <module>()
#       8     name_path = category_path + "/" + category
#       9     for name in [i for i in os.listdir(name_path) if i!=".DS_Store"]:
# ---> 10         folder_path = folder_path + "/" + name
#      11         for img_fn in [i for i in os.listdir(folder) if i!=".DS_Store"]:
#      12             img_path = folder_path + "/" + img_fn
#
# NameError: name 'folder_path' is not defined

# %%
import cv2
import os

ratio = 0.25

category_path = "../data/org"

for category in [category for category in os.listdir(category_path) if category!=".DS_Store"]:
    folder_path = "{}/{}".format(category_path, category)
    to_folder_path = folder_path.replace("org", "detect")
    if not os.path.isdir(to_folder_path):
        os.mkdir(to_folder_path)
    for folder in [folder for folder in os.listdir(folder_path) if folder!=".DS_Store"]:
        name_path = "{}/{}".format(folder_path, folder)
        to_name_path = name_path.replace("org", "detect")
        if not os.path.isdir(to_name_path):
            os.mkdir(to_name_path)
        for name in [name for name in os.listdir(name_path) if name!=".DS_Store"]:
            img_path = "{}/{}".format(name_path, name)
            to_img_path = img_path.replace("org", "detect")
            img = cv2.imread(img_path)
            try:
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
